# %% [markdown]
# <a href="https://colab.research.google.com/github/Kumaaan/PemMes_2026/blob/main/TI_244107020088_Adi_Luhung.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyprep scipy wandb pyecg
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 5.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# !pip install scikit-learn setuptools
# !pip install pyecg --no-dependencies
# Out:
# ...
#   Using cached pyECG-0.0.9.1-py2.py3-none-any.whl.metadata (3.1 kB)
# ...

# %% [markdown]
# Kegunaan Masing-Masing Library:
#
# * PyPREP: Digunakan untuk prapemrosesan data EEG atau sinyal aktivitas otak secara otomatis menggunakan standar PREP pipeline.
# * Scipy: Library inti untuk komputasi ilmiah dan matematika yang berfungsi mengolah array, pemrosesan sinyal, optimasi, dan perhitungan statistik.
# * wandb: Alat pelacak eksperimen machine learning untuk mencatat metrik performa, visualisasi training, dan manajemen dataset.
# * pyECG: Library khusus untuk menganalisis dan memproses sinyal ECG, seperti mendeteksi detak jantung dan ekstraksi fitur sinyal.

# %% [markdown]
# BAGIAN 2
#
# 1. Contoh Pelanggaran Etika dan Hukum AI
#   * Contoh Tindakan: Salah satu contohnya adalah penyalahgunaan teknologi Deepfake untuk memalsukan wajah atau suara orang lain tanpa izin. Biasanya ini dipakai untuk menipu atau menjatuhkan nama baik seseorang. Tindakan ini jelas melanggar etika karena merugikan privasi orang lain. Secara hukum di Indonesia, pelaku yang menyebarkan konten manipulatif seperti ini bisa kena sanksi pidana lewat UU ITE.
#   * Referensi:
#     * UU No. 11 Tahun 2008 tentang Informasi dan Transaksi Elektronik (UU ITE).
#
# 2. Dampak Energi/Lingkungan AI & Solusinya
#   * Dampak Lingkungan: Proses melatih (training) model AI yang ukurannya besar (seperti Chatbot atau LLM) itu butuh komputer berspesifikasi tinggi di data center yang harus menyala terus-menerus. Akibatnya, konsumsi listrik jadi sangat boros, jejak karbon meningkat, dan butuh banyak air bersih hanya untuk mendinginkan mesin servernya.
#   * Cara Mengatasi (Pendapat):
#     * Mengembangkan arsitektur model yang lebih efisien agar tidak boros daya saat dijalankan.
#     * Mewajibkan perusahaan penyedia data center untuk beralih menggunakan sumber energi terbarukan (seperti panel surya atau angin).
#   * Referensi:
#     * Strubell, E., dkk. (2019). Energy and Policy Considerations for Deep Learning in NLP. https://aclanthology.org/P19-1355/
